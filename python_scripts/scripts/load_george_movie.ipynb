# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt

# %%
a = loadmat("/Users/tizianocausin/Desktop/george_113018_data.mat")

# %%
# Show all keys
print("Keys:", a.keys())
print("\n" + "="*50 + "\n")

# Show shape and type of each value
for key in a.keys():
    value = a[key]
    print(f"Key: {key}")
    print(f"  Type: {type(value)}")
    if hasattr(value, 'shape'):
        print(f"  Shape: {value.shape}")
    if hasattr(value, 'dtype'):
        print(f"  Data type: {value.dtype}")
    print()
# Out:
# Keys: dict_keys(['__header__', '__version__', '__globals__', 'UniqueNames', 'imageRF', 'params'])
#
# ==================================================
#
# Key: __header__
#   Type: <class 'bytes'>
#
# Key: __version__
#   Type: <class 'str'>
#
# Key: __globals__
#   Type: <class 'list'>
#
# Key: UniqueNames
#   Type: <class 'numpy.ndarray'>
#   Shape: (1, 4)
#   Data type: object
#
# Key: imageRF
#   Type: <class 'numpy.ndarray'>
#   Shape: (17, 17, 1550, 64, 4)
#   Data type: float64
#
# Key: params
#   Type: <class 'numpy.ndarray'>
#   Shape: (1, 1)
#   Data type: [('shift_x', 'O'), ('background', 'O'), ('Resp_windows', 'O'), ('bankchannels', 'O'), ('smoothingkernel', 'O'), ('maxtime', 'O'), ('volthresh', 'O'), ('array_banks', 'O'), ('ppd', 'O'), ('image_display', 'O'), ('grid_space_map_x', 'O'), ('grid_space_map_y', 'O'), ('image_display_ppd', 'O'), ('numchannels', 'O'), ('timewindow', 'O'), ('data_dir', 'O'), ('image_dir', 'O'), ('curr_date', 'O'), ('stimfolder', 'O')]

# %%
a["imageRF"].shape
# Out:
# (17, 17, 1550, 64, 4)

# %%
plt.figure(figsize=(40,10))
plt.imshow((a["imageRF"][0, 0, :, :, 0]).T, cmap="gray")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1549.5), np.float64(63.5), np.float64(-0.5))

# %%
print(a["imageRF"][0, 0, :5, :5, 0])
# Out:
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   5.00000000e+02]
#  [5.00000000e+02 0.00000000e+00 5.00000000e+02 5.00000000e+02
#   5.00000000e+02]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 5.00000000e+02
#   5.00000000e+02]
#  [5.00000000e+02 0.00000000e+00 5.00000000e+02 3.96508223e-15
#   3.96508223e-15]]

# %%
plt.imshow(a["UniqueNames"][:, :, 0, 0, 0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 plt.imshow(a["UniqueNames"][:, :, 0, 0, 0])
#
# IndexError: too many indices for array: array is 1-dimensional, but 5 were indexed
